# %%
import pandas as pd

# %% [markdown]
# Create Dataframe using in-built function read_csv() in pandas

# %%
df = pd.read_csv('meddata.csv')

# %%
df
# Out:
#         sku_id product_id                         sku_name   price  \
# 0     270721.0    47046.0              Olworm 400mg Tablet     2.5
# 1            -          -             Sovimox CL (500+125)  135.00
# 2     293979.0    48043.0            Montus Kid 4mg Tablet    60.5
# 3     306759.0    53384.0               Zendol 100 Capsule   277.3
# 4     262356.0    40620.0            Azysafe 1000mg Tablet   33.33
# ...        ...        ...                              ...     ...
# 9995         -          -                 Femsave (250 mg)   54.00
# 9996  291325.0    16000.0         Lrn P 8 mg/500 mg Tablet    79.9
# 9997  328204.0     8030.0      Chlorpromazine 100mg Tablet    8.85
# 9998  424852.0   156327.0  Inta-GM 750mg/50mg/250mg Tablet   129.0
# 9999  502840.0   212453.0              Nedrox 500mg Tablet    75.0
#
#                        manufacturer_name  \
# 0      Biochem Pharmaceutical Industries
# 1      Gopal Life Sciences (Sovia Altis)
# 2     Fourrts India Laboratories Pvt Ltd
# 3           Serum Institute Of India Ltd
# 4            Overseas Healthcare Pvt Ltd
# ...                                  ...
# 9995             Fem Care Pharma Limited
# 9996        Glenmark Pharmaceuticals Ltd
# 9997   Sun Pharmaceutical Industries Ltd
# 9998              Mepfarma India Pvt Ltd
# 9999               Neuron Pharma Pvt Ltd
#
#                                           salt_name  drug_form Pack_size  \
# 0                                       Albendazole     Tablet         1
# 1                     Amoxycillin + Clavulanic Acid     Tablet  6 Tablet
# 2                                       Montelukast     Tablet        10
# 3                                           Danazol    Capsule        10
# 4                                      Azithromycin     Tablet         1
# ...                                             ...        ...       ...
# 9995                             Hydroxyprogestrone  Injection      1 ml
# 9996           Lornoxicam+Paracetamol/Acetaminophen     Tablet        10
# 9997                                 Chlorpromazine     Tablet        10
# 9998  Glucosamine+Diacerein+Methyl Sulfonyl Methane     Tablet        10
# 9999                                     Cefadroxil     Tablet        10
#
#                   strength product_banned_flag      unit price_per_unit
# 0                    400mg               False         -              -
# 1          125 mg + 500 mg                   -  1 Tablet          22.50
# 2                      4mg               False         -              -
# 3                    100mg               False         -              -
# 4                   1000mg               False         -              -
# ...                    ...                 ...       ...            ...
# 9995                250 mg                   -      1 ml          54.00
# 9996           8mg + 500mg               False         -              -
# 9997                 100mg               False         -              -
# 9998  750mg + 50mg + 250mg               False         -              -
# 9999                 500mg               False         -              -
#
# [10000 rows x 12 columns]

# %% [markdown]
# In this dataframe we have to fill the values which are not specified

# %%
df = df.replace(to_replace ="-",value ="None")

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Transpose dataframe to convert into dictionary so that we can save this data to our django models by using bulk update_or_create

# %%
transpose_df = df.transpose()

# %%
transpose_df
# Out:
#                                                   0     \
# index                                                0
# sku_id                                        270721.0
# product_id                                     47046.0
# sku_name                           Olworm 400mg Tablet
# price                                              2.5
# manufacturer_name    Biochem Pharmaceutical Industries
# salt_name                                  Albendazole
# drug_form                                       Tablet
# Pack_size                                            1
# strength                                         400mg
# product_banned_flag                              False
# unit                                              None
# price_per_unit                                    None
#
#                                                   1     \
# index                                                1
# sku_id                                            None
# product_id                                        None
# sku_name                          Sovimox CL (500+125)
# price                                           135.00
# manufacturer_name    Gopal Life Sciences (Sovia Altis)
# salt_name                Amoxycillin + Clavulanic Acid
# drug_form                                       Tablet
# Pack_size                                     6 Tablet
# strength                               125 mg + 500 mg
# product_banned_flag                               None
# unit                                          1 Tablet
# price_per_unit                                   22.50
#
#                                                    2     \
# index                                                 2
# sku_id                                         293979.0
# product_id                                      48043.0
# sku_name                          Montus Kid 4mg Tablet
# price                                              60.5
# manufacturer_name    Fourrts India Laboratories Pvt Ltd
# salt_name                                   Montelukast
# drug_form                                        Tablet
# Pack_size                                            10
# strength                                            4mg
# product_banned_flag                               False
# unit                                               None
# price_per_unit                                     None
#
#                                              3     \
# index                                           3
# sku_id                                   306759.0
# product_id                                53384.0
# sku_name                       Zendol 100 Capsule
# price                                       277.3
# manufacturer_name    Serum Institute Of India Ltd
# salt_name                                 Danazol
# drug_form                                 Capsule
# Pack_size                                      10
# strength                                    100mg
# product_banned_flag                         False
# unit                                         None
# price_per_unit                               None
#
#                                             4                     5     \
# index                                          4                     5
# sku_id                                  262356.0              476208.0
# product_id                               40620.0              193852.0
# sku_name                   Azysafe 1000mg Tablet  Rabiclip ITR Capsule
# price                                      33.33                 129.0
# manufacturer_name    Overseas Healthcare Pvt Ltd     Zoic Lifesciences
# salt_name                           Azithromycin  Rabeprazole+Itopride
# drug_form                                 Tablet               Capsule
# Pack_size                                      1                    10
# strength                                  1000mg          20mg + 150mg
# product_banned_flag                        False                 False
# unit                                        None                  None
# price_per_unit                              None                  None
#
#                                        6                              7     \
# index                                     6                              7
# sku_id                                 None                           None
# product_id                             None                           None
# sku_name                    Mucomyks (1 GM)                         Sanflu
# price                                112.00                          40.00
# manufacturer_name    AAA Pharmacuricals Ltd  Sangrose Laboratories Pvt Ltd
# salt_name                    Acetylcysteine                    Fluconazole
# drug_form                         Injection                        Capsule
# Pack_size                              5 ml                      4 Capsule
# strength                               1 gm                         150 mg
# product_banned_flag                    None                           None
# unit                                   1 ml                      1 Capsule
# price_per_unit                        22.40                          10.00
#
#                                              8     \
# index                                           8
# sku_id                                   410112.0
# product_id                               142383.0
# sku_name             Mapcin OZ 200mg/500mg Tablet
# price                                        73.5
# manufacturer_name         Aster Medipharm Pvt Ltd
# salt_name                    Ofloxacin+Ornidazole
# drug_form                                  Tablet
# Pack_size                                      10
# strength                            200mg + 500mg
# product_banned_flag                         False
# unit                                         None
# price_per_unit                               None
#
#                                               9     ...  \
# index                                            9  ...
# sku_id                                        None  ...
# product_id                                    None  ...
# sku_name                       Fludep AZ (0.25+20)  ...
# price                                        35.00  ...
# manufacturer_name    Ultramark Healthcare Pvt Ltd.  ...
# salt_name              Alprazolam + Fluoxetine Hcl  ...
# drug_form                                   Tablet  ...
# Pack_size                                10 Tablet  ...
# strength                           20 mg + 0.25 mg  ...
# product_banned_flag                           None  ...
# unit                                      1 Tablet  ...
# price_per_unit                                3.50  ...
#
#                                                      9990  \
# index                                                9990
# sku_id                                            69429.0
# product_id                                        26663.0
# sku_name                                Aspisol 75 Tablet
# price                                                 8.6
# manufacturer_name            Shreya Life Sciences Pvt Ltd
# salt_name            Aspirin/Acetylsalicylic acid+Glycine
# drug_form                                          Tablet
# Pack_size                                              30
# strength                                    75mg + 37.5mg
# product_banned_flag                                 False
# unit                                                 None
# price_per_unit                                       None
#
#                                                  9991  \
# index                                            9991
# sku_id                                           None
# product_id                                       None
# sku_name                     Caldiron (500 mg+250 iu)
# price                                          343.20
# manufacturer_name    Agron Remedies Pvt Ltd (Agrogem)
# salt_name                  Vit D3 + Calcium Carbonate
# drug_form                                      Tablet
# Pack_size                                  150 Tablet
# strength                              250 iu + 500 mg
# product_banned_flag                              None
# unit                                         1 Tablet
# price_per_unit                                   2.29
#
#                                                     9992  \
# index                                               9992
# sku_id                                          242501.0
# product_id                                       52800.0
# sku_name                       Panoxen AQ 75mg Injection
# price                                               17.5
# manufacturer_name    Anglo-French Drugs & Industries Ltd
# salt_name                                     Diclofenac
# drug_form                                      Injection
# Pack_size                                            1ml
# strength                                            75mg
# product_banned_flag                                False
# unit                                                None
# price_per_unit                                      None
#
#                                      9993                      9994  \
# index                                9993                      9994
# sku_id                               None                  524164.0
# product_id                           None                  229682.0
# sku_name             Amsha Plus (12.5 mg)       Levicalm 250 Tablet
# price                               10.00                      75.0
# manufacturer_name         Suraksha Pharma  Algen Healthcare Pvt Ltd
# salt_name                   Amitriptyline             Levetiracetam
# drug_form                          Tablet                    Tablet
# Pack_size                       10 Tablet                        10
# strength                          12.5 mg                     250mg
# product_banned_flag                  None                     False
# unit                             1 Tablet                      None
# price_per_unit                       1.00                      None
#
#                                         9995  \
# index                                   9995
# sku_id                                  None
# product_id                              None
# sku_name                    Femsave (250 mg)
# price                                  54.00
# manufacturer_name    Fem Care Pharma Limited
# salt_name                 Hydroxyprogestrone
# drug_form                          Injection
# Pack_size                               1 ml
# strength                              250 mg
# product_banned_flag                     None
# unit                                    1 ml
# price_per_unit                         54.00
#
#                                                      9996  \
# index                                                9996
# sku_id                                           291325.0
# product_id                                        16000.0
# sku_name                         Lrn P 8 mg/500 mg Tablet
# price                                                79.9
# manufacturer_name            Glenmark Pharmaceuticals Ltd
# salt_name            Lornoxicam+Paracetamol/Acetaminophen
# drug_form                                          Tablet
# Pack_size                                              10
# strength                                      8mg + 500mg
# product_banned_flag                                 False
# unit                                                 None
# price_per_unit                                       None
#
#                                                   9997  \
# index                                             9997
# sku_id                                        328204.0
# product_id                                      8030.0
# sku_name                   Chlorpromazine 100mg Tablet
# price                                             8.85
# manufacturer_name    Sun Pharmaceutical Industries Ltd
# salt_name                               Chlorpromazine
# drug_form                                       Tablet
# Pack_size                                           10
# strength                                         100mg
# product_banned_flag                              False
# unit                                              None
# price_per_unit                                    None
#
#                                                               9998  \
# index                                                         9998
# sku_id                                                    424852.0
# product_id                                                156327.0
# sku_name                           Inta-GM 750mg/50mg/250mg Tablet
# price                                                        129.0
# manufacturer_name                           Mepfarma India Pvt Ltd
# salt_name            Glucosamine+Diacerein+Methyl Sulfonyl Methane
# drug_form                                                   Tablet
# Pack_size                                                       10
# strength                                      750mg + 50mg + 250mg
# product_banned_flag                                          False
# unit                                                          None
# price_per_unit                                                None
#
#                                       9999
# index                                 9999
# sku_id                            502840.0
# product_id                        212453.0
# sku_name               Nedrox 500mg Tablet
# price                                 75.0
# manufacturer_name    Neuron Pharma Pvt Ltd
# salt_name                       Cefadroxil
# drug_form                           Tablet
# Pack_size                               10
# strength                             500mg
# product_banned_flag                  False
# unit                                  None
# price_per_unit                        None
#
# [13 rows x 10000 columns]

# %%
final_df = transpose_df.to_dict()

# %%
final_df
# Out:
# {0: {'index': 0,
#   'sku_id': '270721.0',
#   'product_id': '47046.0',
#   'sku_name': 'Olworm 400mg Tablet',
#   'price': '2.5',
#   'manufacturer_name': 'Biochem Pharmaceutical Industries',
#   'salt_name': 'Albendazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '1',
#   'strength': '400mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  1: {'index': 1,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Sovimox CL (500+125)',
#   'price': '135.00',
#   'manufacturer_name': 'Gopal Life Sciences (Sovia Altis)',
#   'salt_name': 'Amoxycillin + Clavulanic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '6 Tablet',
#   'strength': '125 mg + 500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '22.50'},
#  2: {'index': 2,
#   'sku_id': '293979.0',
#   'product_id': '48043.0',
#   'sku_name': 'Montus Kid 4mg Tablet',
#   'price': '60.5',
#   'manufacturer_name': 'Fourrts India Laboratories Pvt Ltd',
#   'salt_name': 'Montelukast',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '4mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  3: {'index': 3,
#   'sku_id': '306759.0',
#   'product_id': '53384.0',
#   'sku_name': 'Zendol 100 Capsule',
#   'price': '277.3',
#   'manufacturer_name': 'Serum Institute Of India Ltd',
#   'salt_name': 'Danazol',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '100mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  4: {'index': 4,
#   'sku_id': '262356.0',
#   'product_id': '40620.0',
#   'sku_name': 'Azysafe 1000mg Tablet',
#   'price': '33.33',
#   'manufacturer_name': 'Overseas Healthcare Pvt Ltd',
#   'salt_name': 'Azithromycin',
#   'drug_form': 'Tablet',
#   'Pack_size': '1',
#   'strength': '1000mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  5: {'index': 5,
#   'sku_id': '476208.0',
#   'product_id': '193852.0',
#   'sku_name': 'Rabiclip ITR Capsule',
#   'price': '129.0',
#   'manufacturer_name': 'Zoic Lifesciences',
#   'salt_name': 'Rabeprazole+Itopride',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '20mg + 150mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  6: {'index': 6,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Mucomyks (1 GM)',
#   'price': '112.00',
#   'manufacturer_name': 'AAA Pharmacuricals Ltd',
#   'salt_name': 'Acetylcysteine',
#   'drug_form': 'Injection',
#   'Pack_size': '5 ml',
#   'strength': '1 gm',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '22.40'},
#  7: {'index': 7,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Sanflu',
#   'price': '40.00',
#   'manufacturer_name': 'Sangrose Laboratories Pvt Ltd',
#   'salt_name': 'Fluconazole',
#   'drug_form': 'Capsule',
#   'Pack_size': '4 Capsule',
#   'strength': '150 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '10.00'},
#  8: {'index': 8,
#   'sku_id': '410112.0',
#   'product_id': '142383.0',
#   'sku_name': 'Mapcin OZ 200mg/500mg Tablet',
#   'price': '73.5',
#   'manufacturer_name': 'Aster Medipharm Pvt Ltd',
#   'salt_name': 'Ofloxacin+Ornidazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg + 500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  9: {'index': 9,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Fludep AZ (0.25+20)',
#   'price': '35.00',
#   'manufacturer_name': 'Ultramark Healthcare Pvt Ltd.',
#   'salt_name': 'Alprazolam + Fluoxetine Hcl',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '20 mg + 0.25 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '3.50'},
#  10: {'index': 10,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Povicidal (Skin) (20 gm)',
#   'price': '29.00',
#   'manufacturer_name': 'Cadila Healthcare Ltd (Zydus Cadila Healthcare Ltd)',
#   'salt_name': 'Povidone Iodine',
#   'drug_form': 'Gel',
#   'Pack_size': '20 gm',
#   'strength': '5%',
#   'product_banned_flag': 'None',
#   'unit': '20 gm',
#   'price_per_unit': '29.00'},
#  11: {'index': 11,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Meco J (1000 mcg)',
#   'price': '24.90',
#   'manufacturer_name': 'Jeen Healthcare',
#   'salt_name': 'Methylcobalamin',
#   'drug_form': 'Injection',
#   'Pack_size': '2 ml',
#   'strength': '500 mcg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '12.45'},
#  12: {'index': 12,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Jupiros F',
#   'price': '140.00',
#   'manufacturer_name': 'Alkem Laboratories Ltd',
#   'salt_name': 'Fenofibrate + Rosuvastatin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '160 mg + 10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '14.00'},
#  13: {'index': 13,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Arsunex (60 mg)',
#   'price': '78.00',
#   'manufacturer_name': 'Hamax Pharmaceuticals',
#   'salt_name': 'Artesunate',
#   'drug_form': 'Tablet',
#   'Pack_size': '6 Tablet',
#   'strength': '60 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '13.00'},
#  14: {'index': 14,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Mebzol (400 mg)',
#   'price': '13.50',
#   'manufacturer_name': 'Esskay Bee Pharma',
#   'salt_name': 'Albendazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '1 Tablet',
#   'strength': '400 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '13.50'},
#  15: {'index': 15,
#   'sku_id': '259254.0',
#   'product_id': '53746.0',
#   'sku_name': 'Melozine 25mg Tablet',
#   'price': '16.0',
#   'manufacturer_name': 'Intas Pharmaceuticals Ltd',
#   'salt_name': 'Thioridazine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '25mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  16: {'index': 16,
#   'sku_id': '448321.0',
#   'product_id': '168615.0',
#   'sku_name': 'Sys 10mg Tablet',
#   'price': '27.9',
#   'manufacturer_name': 'Biosysmedisciences',
#   'salt_name': 'Isoxsuprine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  17: {'index': 17,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Nexcobal (1000 mcg)',
#   'price': '59.00',
#   'manufacturer_name': 'Nexus Biotech',
#   'salt_name': 'Methylcobalamin',
#   'drug_form': 'Injection',
#   'Pack_size': '2 ml',
#   'strength': '500 mcg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '29.50'},
#  18: {'index': 18,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Bactol (250 mg)',
#   'price': '567.00',
#   'manufacturer_name': 'Medoz Pharmaceuticals',
#   'salt_name': 'Amoxicillin Trihydrate',
#   'drug_form': 'Capsule',
#   'Pack_size': '150 Capsule',
#   'strength': '250 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '3.78'},
#  19: {'index': 19,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Kapiclid 600',
#   'price': '125.00',
#   'manufacturer_name': 'Godrams Lifeline',
#   'salt_name': 'Clindamycin',
#   'drug_form': 'Injection',
#   'Pack_size': '4 ml',
#   'strength': '600 mg',
#   'product_banned_flag': 'None',
#   'unit': '4 ml',
#   'price_per_unit': '125.00'},
#  20: {'index': 20,
#   'sku_id': '301093.0',
#   'product_id': '53064.0',
#   'sku_name': 'Olitabs 7.5mg Tablet',
#   'price': '37.48',
#   'manufacturer_name': 'KC Laboratories',
#   'salt_name': 'Olanzapine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '7.5mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  21: {'index': 21,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Ddd 60K Tablet',
#   'price': '47.0',
#   'manufacturer_name': 'J B Chemicals and Pharmaceuticals Ltd',
#   'salt_name': 'Cholecalciferol',
#   'drug_form': 'Tablet',
#   'Pack_size': 'strip of 4 tablets',
#   'strength': '60,000iu',
#   'product_banned_flag': 'None',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  22: {'index': 22,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Daoryl M (2+500)',
#   'price': '40.00',
#   'manufacturer_name': 'J.B. Chemicals & Pharmaceuticals Ltd.',
#   'salt_name': 'Glimepiride + Metformin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '500 mg + 2 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.00'},
#  23: {'index': 23,
#   'sku_id': '421312.0',
#   'product_id': '152992.0',
#   'sku_name': 'Nexamin 500mg Tablet',
#   'price': '159.8',
#   'manufacturer_name': 'Medimark Biotech',
#   'salt_name': 'Tranexamic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  24: {'index': 24,
#   'sku_id': '429978.0',
#   'product_id': '160265.0',
#   'sku_name': 'Ampen 40mg Injection',
#   'price': '50.0',
#   'manufacturer_name': 'Health Biotech Limited',
#   'salt_name': 'Pantoprazole',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '40mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  25: {'index': 25,
#   'sku_id': '531972.0',
#   'product_id': '236389.0',
#   'sku_name': 'Atycort 30mg Tablet',
#   'price': '370.0',
#   'manufacturer_name': 'Atyad Life Sciences Pvt Ltd',
#   'salt_name': 'Deflazacort',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '30mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  26: {'index': 26,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Anorcin-TZ (400+600)',
#   'price': '490.00',
#   'manufacturer_name': 'Shrinivas (Gujarat) Laboratories Pvt. Ltd.',
#   'salt_name': 'Norfloxacin + Tinidazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '100 Tablet',
#   'strength': '600 mg + 400 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.90'},
#  27: {'index': 27,
#   'sku_id': '510306.0',
#   'product_id': '218353.0',
#   'sku_name': 'Amirix 250mg Injection',
#   'price': '32.0',
#   'manufacturer_name': 'Human Biolife India Pvt Ltd',
#   'salt_name': 'Amikacin',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '250mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  28: {'index': 28,
#   'sku_id': '530725.0',
#   'product_id': '235197.0',
#   'sku_name': 'Redzox 500mg/50mg/500mg Tablet',
#   'price': '31.2',
#   'manufacturer_name': 'Marc Laboratories Pvt Ltd',
#   'salt_name': 'Chlorzoxazone+Diclofenac+Paracetamol/Acetaminophen',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '500mg + 50mg + 500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  29: {'index': 29,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Eldtam (10 mg)',
#   'price': '26.33',
#   'manufacturer_name': 'Elder Pharmaceuticals Pvt Ltd',
#   'salt_name': 'Tamoxifen',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.63'},
#  30: {'index': 30,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Orbil (200 mg)',
#   'price': '22.00',
#   'manufacturer_name': 'Neon Laboratories Ltd',
#   'salt_name': 'Albendazole',
#   'drug_form': 'Suspension',
#   'Pack_size': '10 ml',
#   'strength': '200 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '11.00'},
#  31: {'index': 31,
#   'sku_id': '367931.0',
#   'product_id': '112654.0',
#   'sku_name': 'Rifeasy 550 Tablet',
#   'price': '325.0',
#   'manufacturer_name': 'MSN Laboratories',
#   'salt_name': 'Rifaximin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '550mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  32: {'index': 32,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Acupil (5 mg)',
#   'price': '41.60',
#   'manufacturer_name': 'Pfizer Limited (Pharmacia India Pvt Ltd)',
#   'salt_name': 'Quinapril',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '5 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.16'},
#  33: {'index': 33,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Quintor TZ (500+600)',
#   'price': '85.00',
#   'manufacturer_name': 'Vista (Torrent Pharmaceuticals Ltd.)',
#   'salt_name': 'Ciprofloxacin + Tinidazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '600 mg + 500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '8.50'},
#  34: {'index': 34,
#   'sku_id': '494864.0',
#   'product_id': '208927.0',
#   'sku_name': 'Cufdoz L Syrup',
#   'price': '75.0',
#   'manufacturer_name': 'Stensa Life Sciences',
#   'salt_name': 'Levosalbutamol/Levalbuterol+Ambroxol+Guaifenesin',
#   'drug_form': 'Syrup',
#   'Pack_size': '100ml',
#   'strength': '1mg + 30mg + 50mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  35: {'index': 35,
#   'sku_id': '464736.0',
#   'product_id': '183631.0',
#   'sku_name': 'Dedep S 20mg Tablet',
#   'price': '92.26',
#   'manufacturer_name': 'Kiosence Health Care Pvt Ltd',
#   'salt_name': 'Escitalopram Oxalate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  36: {'index': 36,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rover (500+500)',
#   'price': '249.00',
#   'manufacturer_name': 'Innovative Pharmaceuticals',
#   'salt_name': 'Sulbactam + Cefoperazone',
#   'drug_form': 'Injection',
#   'Pack_size': '1 Vial',
#   'strength': '500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Vial',
#   'price_per_unit': '249.00'},
#  37: {'index': 37,
#   'sku_id': '369031.0',
#   'product_id': '113588.0',
#   'sku_name': 'Triosin D Tablet',
#   'price': '180.0',
#   'manufacturer_name': 'Signova Pharma Pvt Ltd',
#   'salt_name': 'Trypsin+Bromelain+Rutoside+Diclofenac',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '48mg + 90mg + 100mg + 50mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  38: {'index': 38,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Epinor (4 mg)',
#   'price': '125.00',
#   'manufacturer_name': 'Geo Pharma Pvt Ltd',
#   'salt_name': 'Norepinephrine',
#   'drug_form': 'Injection',
#   'Pack_size': '2 ml',
#   'strength': '4 mg',
#   'product_banned_flag': 'None',
#   'unit': '2 ml',
#   'price_per_unit': '125.00'},
#  39: {'index': 39,
#   'sku_id': '448074.0',
#   'product_id': '168380.0',
#   'sku_name': 'Rej O 300mg Tablet',
#   'price': '52.0',
#   'manufacturer_name': 'Ubit Pharmaceuticals Pvt Ltd',
#   'salt_name': 'Quinine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '300mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  40: {'index': 40,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Pararose (125 mg)',
#   'price': '23.95',
#   'manufacturer_name': 'Ronyd Healthcare (P) Ltd',
#   'salt_name': 'Paracetamol',
#   'drug_form': 'Suspension',
#   'Pack_size': '60 ml',
#   'strength': '125 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '2.00'},
#  41: {'index': 41,
#   'sku_id': '425614.0',
#   'product_id': '157066.0',
#   'sku_name': 'Pakmol 150mg Injection',
#   'price': '3.0',
#   'manufacturer_name': 'Paksons Pharmaceuticals Pvt Ltd',
#   'salt_name': 'Paracetamol/Acetaminophen',
#   'drug_form': 'Injection',
#   'Pack_size': '2ml',
#   'strength': '150mg/ml',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  42: {'index': 42,
#   'sku_id': '485389.0',
#   'product_id': '200929.0',
#   'sku_name': 'Mood On 0.5mg/10mg Tablet',
#   'price': '65.0',
#   'manufacturer_name': 'Laxian Healthcare',
#   'salt_name': 'Flupenthixol+Melitracen',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '0.5mg + 10mg',
#   'product_banned_flag': 'True',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  43: {'index': 43,
#   'sku_id': '305479.0',
#   'product_id': '64802.0',
#   'sku_name': 'Cefpen S 250 mg/125 mg Injection',
#   'price': '49.95',
#   'manufacturer_name': 'Morepen Laboratories Ltd',
#   'salt_name': 'Ceftriaxone+Sulbactam',
#   'drug_form': 'Injection',
#   'Pack_size': '10ml',
#   'strength': '250mg + 125mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  44: {'index': 44,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Azithm 500',
#   'price': '200.00',
#   'manufacturer_name': 'Rhythm Medicare',
#   'salt_name': 'Azithromycin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '20.00'},
#  45: {'index': 45,
#   'sku_id': '421453.0',
#   'product_id': '153131.0',
#   'sku_name': 'Odipin 10mg Tablet',
#   'price': '14.0',
#   'manufacturer_name': 'Biocin Healthcare',
#   'salt_name': 'Amlodipine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  46: {'index': 46,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Dase DP (10+50+325)',
#   'price': '30.00',
#   'manufacturer_name': 'Nutramed Pharmaceuticals Pvt. Ltd.',
#   'salt_name': 'Serratiopeptidase + Diclofenac Potassium + Paracetamol',
#   'drug_form': 'Tablet',
#   'Pack_size': '6 Tablet',
#   'strength': '325 mg + 50 mg + 10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '5.00'},
#  47: {'index': 47,
#   'sku_id': '480826.0',
#   'product_id': '197574.0',
#   'sku_name': 'Rispomac 2mg Tablet',
#   'price': '40.0',
#   'manufacturer_name': 'Macway Biotech Pvt Ltd',
#   'salt_name': 'Risperidone',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '2mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  48: {'index': 48,
#   'sku_id': '473997.0',
#   'product_id': '192203.0',
#   'sku_name': 'Orid 20mg Capsule',
#   'price': '47.3',
#   'manufacturer_name': 'Welkind Pharma',
#   'salt_name': 'Omeprazole',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  49: {'index': 49,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Nano CV 875 mg/125 mg Tablet',
#   'price': '100.0',
#   'manufacturer_name': 'Aigis Biotec',
#   'salt_name': 'Amoxycillin+Clavulanic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': 'strip of 4 tablets',
#   'strength': '875Mg+125Mg',
#   'product_banned_flag': 'None',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  50: {'index': 50,
#   'sku_id': '419297.0',
#   'product_id': '151068.0',
#   'sku_name': 'Zipodox O 50mg Dry Syrup',
#   'price': '79.0',
#   'manufacturer_name': 'Orsis Pharmaceuticals',
#   'salt_name': 'Cefpodoxime Proxetil',
#   'drug_form': 'Dry Syrup',
#   'Pack_size': '30ml',
#   'strength': '50mg/5ml',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  51: {'index': 51,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'LG Intermax Alpha (3 mil iu)',
#   'price': '1 150.00',
#   'manufacturer_name': 'LG Life Sciences India',
#   'salt_name': 'Interferon Alpha 2A',
#   'drug_form': 'Injection',
#   'Pack_size': '1 Vial',
#   'strength': '3 million iu',
#   'product_banned_flag': 'None',
#   'unit': '1 Vial',
#   'price_per_unit': '1 150.00'},
#  52: {'index': 52,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Decodil X (8+2)',
#   'price': '6.50',
#   'manufacturer_name': 'Ortin Laboratories Ltd',
#   'salt_name': 'Salbutamol + Bromhexine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '8 mg + 2 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '0.65'},
#  53: {'index': 53,
#   'sku_id': '267267.0',
#   'product_id': '21453.0',
#   'sku_name': 'Vertop 8mg Tablet',
#   'price': '27.0',
#   'manufacturer_name': 'Theo Pharma Pvt Ltd',
#   'salt_name': 'Betahistine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '8mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  54: {'index': 54,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Farlutal (10 mg)',
#   'price': '50.36',
#   'manufacturer_name': 'Pharmacia & Upjohn',
#   'salt_name': 'Medroxy Progesterone Acetate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '5.04'},
#  55: {'index': 55,
#   'sku_id': '531150.0',
#   'product_id': '235599.0',
#   'sku_name': 'Gaballa M 300mg/750mcg Tablet',
#   'price': '125.0',
#   'manufacturer_name': 'Wells Biosciences',
#   'salt_name': 'Gabapentin+Methylcobalamin/Mecobalamin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '300mg + 750mcg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  56: {'index': 56,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Zilee (750 mg)',
#   'price': '39.00',
#   'manufacturer_name': 'Lumina (FDC Limited)',
#   'salt_name': 'Levofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '5 Tablet',
#   'strength': '750 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '7.80'},
#  57: {'index': 57,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Angitrate (10 mg)',
#   'price': '104.00',
#   'manufacturer_name': 'Tosc International Pvt Ltd.',
#   'salt_name': 'Isosorbide 5 Mononitrate',
#   'drug_form': 'Tablet',
#   'Pack_size': '100 Tablet',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '1.04'},
#  58: {'index': 58,
#   'sku_id': '421207.0',
#   'product_id': '152887.0',
#   'sku_name': 'Gotam 0.4mg Tablet',
#   'price': '67.9',
#   'manufacturer_name': 'Cmg Biotech Pvt Ltd',
#   'salt_name': 'Tamsulosin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '0.4mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  59: {'index': 59,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Pefran (400 mg)',
#   'price': '45.00',
#   'manufacturer_name': 'Biochem Pharmaceutical Industrial Ltd',
#   'salt_name': 'Pefloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '400 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.50'},
#  60: {'index': 60,
#   'sku_id': '30817.0',
#   'product_id': '42139.0',
#   'sku_name': 'Respidon 1 Tablet',
#   'price': '20.97',
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'salt_name': 'Risperidone',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '1mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  61: {'index': 61,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Nisdrox (500 mg)',
#   'price': '72.90',
#   'manufacturer_name': 'Neiss Labs Pvt. Ltd.',
#   'salt_name': 'Cefadroxil',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '7.29'},
#  62: {'index': 62,
#   'sku_id': '471001.0',
#   'product_id': '189501.0',
#   'sku_name': 'Clofen 100mg Tablet',
#   'price': '24.9',
#   'manufacturer_name': 'Sansill Formulations',
#   'salt_name': 'Aceclofenac',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '100mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  63: {'index': 63,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Omzol (20 mg)',
#   'price': '49.00',
#   'manufacturer_name': 'Synmedic Laboratories',
#   'salt_name': 'Omeprazole',
#   'drug_form': 'Capsule',
#   'Pack_size': '20 Capsule',
#   'strength': '20 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '2.45'},
#  64: {'index': 64,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'GRD (200 gm)',
#   'price': '173.00',
#   'manufacturer_name': 'Zydus Cadila Healthcare Ltd',
#   'salt_name': 'Protein + Carbohydrate + Folic Acid (Vit B9) + Vit B2 + Vit B1 + Vit B12 + Vit C + Vit B6 + Vit D3 + Manganese Sulphate + Nicotinamide + Calcium Pantothenate + Copper Sulphate + Elemental Iron + Vit A + Dicalcium Phosphate',
#   'drug_form': 'Powder',
#   'Pack_size': '200 gm',
#   'strength': '20 gm + 50 mg + 30 mg + 4.5 mg + 333 iu + 63 gm + 83 mg + 0.1 mg + 1.6 mcg + 1330 mg + 3.3 mg + 1.6 mg + 5330 iu + 1 mg',
#   'product_banned_flag': 'None',
#   'unit': '100 gm',
#   'price_per_unit': '86.50'},
#  65: {'index': 65,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Nucid (170 ml)',
#   'price': '42.00',
#   'manufacturer_name': 'Medinova Lab',
#   'salt_name': 'Magaldrate + Simethicone',
#   'drug_form': 'Syrup',
#   'Pack_size': '170 ml',
#   'strength': '400 mg + 20 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '1.24'},
#  66: {'index': 66,
#   'sku_id': '423659.0',
#   'product_id': '155189.0',
#   'sku_name': 'Maxef 200mg Tablet',
#   'price': '95.0',
#   'manufacturer_name': 'Macved Pharmaceuticals',
#   'salt_name': 'Cefixime',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  67: {'index': 67,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rumalef (10 mg)',
#   'price': '90.10',
#   'manufacturer_name': 'Zydus Cadila Healthcare Ltd',
#   'salt_name': 'Leflunomide',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '9.01'},
#  68: {'index': 68,
#   'sku_id': '458866.0',
#   'product_id': '178077.0',
#   'sku_name': 'Q Flox 200mg Tablet',
#   'price': '55.0',
#   'manufacturer_name': 'Fairdeal Formulations (India) Pvt Ltd',
#   'salt_name': 'Ofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  69: {'index': 69,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Gatirol (400 mg)',
#   'price': '79.80',
#   'manufacturer_name': 'Pharmatech Healthcare',
#   'salt_name': 'Gatifloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '400 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '7.98'},
#  70: {'index': 70,
#   'sku_id': '525104.0',
#   'product_id': '230457.0',
#   'sku_name': 'Alezith 250mg Tablet',
#   'price': '59.8',
#   'manufacturer_name': 'Treatwell Biotech',
#   'salt_name': 'Azithromycin',
#   'drug_form': 'Tablet',
#   'Pack_size': '6',
#   'strength': '250mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  71: {'index': 71,
#   'sku_id': '245480.0',
#   'product_id': '63488.0',
#   'sku_name': 'Oflomine OZ Tablet',
#   'price': '68.55',
#   'manufacturer_name': 'Icon Life Sciences',
#   'salt_name': 'Ofloxacin+Ornidazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg + 500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  72: {'index': 72,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Oflamk 200 Tablet',
#   'price': '89.0',
#   'manufacturer_name': 'Mk Healthcare',
#   'salt_name': 'Ofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': 'strip of 10 tablets',
#   'strength': '200Mg',
#   'product_banned_flag': 'None',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  73: {'index': 73,
#   'sku_id': '318913.0',
#   'product_id': '25894.0',
#   'sku_name': 'Taxedol 20mg Injection',
#   'price': '6500.0',
#   'manufacturer_name': 'Venus Remedies Ltd',
#   'salt_name': 'Docetaxel',
#   'drug_form': 'Injection',
#   'Pack_size': '1ml',
#   'strength': '20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  74: {'index': 74,
#   'sku_id': '271297.0',
#   'product_id': '9319.0',
#   'sku_name': 'Maclitaxel 260mg Injection',
#   'price': '3678.75',
#   'manufacturer_name': 'Macleods Pharmaceuticals Pvt Ltd',
#   'salt_name': 'Paclitaxel',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '260mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  75: {'index': 75,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Cartiglu (750+1.5)',
#   'price': '61.00',
#   'manufacturer_name': 'Prompt Cure Pharma Pvt Ltd',
#   'salt_name': 'Glucosamine Sulphate + Manganese Sulphate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '750 mg + 1.5 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '6.10'},
#  76: {'index': 76,
#   'sku_id': '336084.0',
#   'product_id': '93821.0',
#   'sku_name': 'Chymapra D Tablet',
#   'price': '132.0',
#   'manufacturer_name': 'Mapra Laboratories Pvt Ltd',
#   'salt_name': 'Bromelain+Diclofenac+Rutoside+Trypsin Chymotrypsin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': 'NA + NA + NA + NA',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  77: {'index': 77,
#   'sku_id': '424316.0',
#   'product_id': '155820.0',
#   'sku_name': 'Kyonim-P 100mg/325mg Tablet',
#   'price': '28.0',
#   'manufacturer_name': 'Lifekyor Pharmaceuticals',
#   'salt_name': 'Nimesulide+Paracetamol/Acetaminophen',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '100mg + 325mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  78: {'index': 78,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rise D3',
#   'price': '69.00',
#   'manufacturer_name': 'Nilrise Pharmaceuticals Pvt. Ltd.',
#   'salt_name': 'Cholecalciferol',
#   'drug_form': 'Tablet',
#   'Pack_size': '6 Tablet',
#   'strength': '60000 iu',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '11.50'},
#  79: {'index': 79,
#   'sku_id': '322185.0',
#   'product_id': '14441.0',
#   'sku_name': 'Cozy-Kid Oral Liquid',
#   'price': '59.0',
#   'manufacturer_name': 'Ind Swift Laboratories Ltd',
#   'salt_name': 'Chlorpheniramine Maleate+Paracetamol/Acetaminophen+Phenylephrine',
#   'drug_form': 'Oral Liquid',
#   'Pack_size': '60ml',
#   'strength': '2mg + 125mg + 2.5mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  80: {'index': 80,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'MInoclav DT (200+28.5)',
#   'price': '79.50',
#   'manufacturer_name': 'Minova Life Sciences Pvt Ltd',
#   'salt_name': 'Amoxycillin + Clavulanic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '6 Tablet',
#   'strength': '200 mg + 28.5 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '13.25'},
#  81: {'index': 81,
#   'sku_id': '406149.0',
#   'product_id': '139268.0',
#   'sku_name': 'Clinton 600mg Injection',
#   'price': '169.0',
#   'manufacturer_name': 'Sympar Life Sciences',
#   'salt_name': 'Clarithromycin',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '600mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  82: {'index': 82,
#   'sku_id': '232676.0',
#   'product_id': '37250.0',
#   'sku_name': 'Glenfine 120mg Tablet',
#   'price': '28.6',
#   'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#   'salt_name': 'Fexofenadine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '120mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  83: {'index': 83,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Akralic 12%',
#   'price': '51.00',
#   'manufacturer_name': 'Sangrose Laboratories Pvt Ltd',
#   'salt_name': 'Salicylic Acid',
#   'drug_form': 'Ointment',
#   'Pack_size': '30 gm',
#   'strength': '12%',
#   'product_banned_flag': 'None',
#   'unit': '30 gm',
#   'price_per_unit': '51.00'},
#  84: {'index': 84,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Nulide Plus (100+500)',
#   'price': '28.00',
#   'manufacturer_name': 'Allied Chemicals & Pharmaceuticals Pvt.Ltd.',
#   'salt_name': 'Nimesulide + Paracetamol',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '100 mg + 500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.80'},
#  85: {'index': 85,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Clofung gm Ointment',
#   'price': '18.82',
#   'manufacturer_name': 'Taurus Laboratories Pvt Ltd',
#   'salt_name': 'Beclometasone (Na)+Gentamicin (Na)+Miconazole (Na)+Chlorocresol (Na)',
#   'drug_form': 'Ointment',
#   'Pack_size': 'tube of 5 gm Ointment',
#   'strength': 'None',
#   'product_banned_flag': 'None',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  86: {'index': 86,
#   'sku_id': '462932.0',
#   'product_id': '181900.0',
#   'sku_name': 'Ducoxib 120mg Tablet',
#   'price': '129.0',
#   'manufacturer_name': 'Aurel Biolife',
#   'salt_name': 'Etoricoxib',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '120mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  87: {'index': 87,
#   'sku_id': '149478.0',
#   'product_id': '55180.0',
#   'sku_name': 'Tambac-CV 200 Tablet',
#   'price': '272.0',
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'salt_name': 'Cefpodoxime Proxetil+Clavulanic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg + 125mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  88: {'index': 88,
#   'sku_id': '227850.0',
#   'product_id': '41124.0',
#   'sku_name': 'Fungiban 150mg Tablet',
#   'price': '17.5',
#   'manufacturer_name': 'Medo Pharma',
#   'salt_name': 'Fluconazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '1',
#   'strength': '150mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  89: {'index': 89,
#   'sku_id': '497473.0',
#   'product_id': '211101.0',
#   'sku_name': 'Hormonorm 25mcg Tablet',
#   'price': '120.0',
#   'manufacturer_name': 'Ambrocia Life Sciences',
#   'salt_name': 'Thyroxine/Levothyroxine',
#   'drug_form': 'Tablet',
#   'Pack_size': '100',
#   'strength': '25mcg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  90: {'index': 90,
#   'sku_id': '289808.0',
#   'product_id': '72292.0',
#   'sku_name': 'Kipnol Plus Tablet',
#   'price': '94.72',
#   'manufacturer_name': 'Kivi Labs Ltd',
#   'salt_name': 'Propranolol+Flunarizine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '40mg + 10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  91: {'index': 91,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'LGP H (250 MG)',
#   'price': '89.90',
#   'manufacturer_name': 'Little Greave Pharmaceuticals Ltd.',
#   'salt_name': 'Hydroxyprogestrone Caproate',
#   'drug_form': 'Injection',
#   'Pack_size': '1 ml',
#   'strength': '250 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '89.90'},
#  92: {'index': 92,
#   'sku_id': '460401.0',
#   'product_id': '179533.0',
#   'sku_name': 'Darba 40mcg Injection',
#   'price': '2200.0',
#   'manufacturer_name': 'RPG Life Sciences Ltd',
#   'salt_name': 'Darbepoetin alfa',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '40mcg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  93: {'index': 93,
#   'sku_id': '470655.0',
#   'product_id': '189179.0',
#   'sku_name': 'Panmate 10000mg Capsule',
#   'price': '165.0',
#   'manufacturer_name': 'Hetero Drugs Ltd',
#   'salt_name': 'Pancreatin',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '10000mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  94: {'index': 94,
#   'sku_id': '491869.0',
#   'product_id': '206360.0',
#   'sku_name': 'Allefast 180mg Tablet',
#   'price': '73.25',
#   'manufacturer_name': 'Sterling lab',
#   'salt_name': 'Fexofenadine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '180mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  95: {'index': 95,
#   'sku_id': '264532.0',
#   'product_id': '58157.0',
#   'sku_name': 'Rtsunate SP 50 mg/500 mg/25 mg Tablet',
#   'price': '66.0',
#   'manufacturer_name': 'Themis Medicare Ltd',
#   'salt_name': 'Artesunate+Sulfadoxine+Pyrimethamine',
#   'drug_form': 'Tablet',
#   'Pack_size': '4',
#   'strength': '50mg + 500mg + 25mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  96: {'index': 96,
#   'sku_id': '410212.0',
#   'product_id': '142482.0',
#   'sku_name': 'Montego 100mg Tablet DT',
#   'price': '135.0',
#   'manufacturer_name': 'Ikon Remedies Pvt Ltd',
#   'salt_name': 'Cefpodoxime Proxetil',
#   'drug_form': 'Tablet DT',
#   'Pack_size': '10',
#   'strength': '100mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  97: {'index': 97,
#   'sku_id': '464706.0',
#   'product_id': '183603.0',
#   'sku_name': 'Ruler 30mg/20mg Capsule',
#   'price': '75.0',
#   'manufacturer_name': 'Dhara Formulation Pvt Ltd',
#   'salt_name': 'Domperidone+Rabeprazole',
#   'drug_form': 'Capsule SR',
#   'Pack_size': '10',
#   'strength': '30mg + 20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  98: {'index': 98,
#   'sku_id': '455548.0',
#   'product_id': '175049.0',
#   'sku_name': 'Osomide 750mg Tablet',
#   'price': '52.0',
#   'manufacturer_name': 'Osho Pharma Pvt Ltd',
#   'salt_name': 'Pyrazinamide',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '750mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  99: {'index': 99,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Neuroapt',
#   'price': '80.00',
#   'manufacturer_name': 'APT Cure Laboratories',
#   'salt_name': 'Methylcobalamin + Alpha Lipoic Acid + Pyridoxine Hydrochloride IP + Folic Acid (Vit B9)',
#   'drug_form': 'Capsule',
#   'Pack_size': '10 Capsule',
#   'strength': '500 mcg + 3 mg + 1.5 mg + 100 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '8.00'},
#  100: {'index': 100,
#   'sku_id': '369442.0',
#   'product_id': '113950.0',
#   'sku_name': 'Trulide 100mg Tablet MD',
#   'price': '29.0',
#   'manufacturer_name': 'Rishab Healthcare pvt. Ltd.',
#   'salt_name': 'Nimesulide',
#   'drug_form': 'Tablet MD',
#   'Pack_size': '10',
#   'strength': '100mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  101: {'index': 101,
#   'sku_id': '447734.0',
#   'product_id': '168052.0',
#   'sku_name': 'Prigma-M 750mcg/75mg Capsule',
#   'price': '148.0',
#   'manufacturer_name': 'Aishwarya Healthcare',
#   'salt_name': 'Methylcobalamin/Mecobalamin+Pregabalin',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '750mcg + 75mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  102: {'index': 102,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'I Surax (Inj)',
#   'price': '97.00',
#   'manufacturer_name': 'Rax Health Care Pvt. Ltd.',
#   'salt_name': 'Elemental Iron',
#   'drug_form': 'Injection',
#   'Pack_size': '2.5 ml',
#   'strength': '20 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '38.80'},
#  103: {'index': 103,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Lecourse (750 mg)',
#   'price': '130.00',
#   'manufacturer_name': 'Cyno Pharmaceuticals  Ltd.',
#   'salt_name': 'Levofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '750 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '13.00'},
#  104: {'index': 104,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Monaz LC (10+5)',
#   'price': '129.85',
#   'manufacturer_name': 'Auztus Laboratories Pvt. Ltd.',
#   'salt_name': 'Montelukast + Levocetirizine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '5 mg + 10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '12.99'},
#  105: {'index': 105,
#   'sku_id': '120321.0',
#   'product_id': '10051.0',
#   'sku_name': 'Parkin Tablet',
#   'price': '12.77',
#   'manufacturer_name': 'Micro Labs Ltd',
#   'salt_name': 'Trihexyphenidyl/Benzhexol',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '2mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  106: {'index': 106,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Aziral (15 ml)',
#   'price': '23.25',
#   'manufacturer_name': 'Hiral Labs Ltd.',
#   'salt_name': 'Azithromycin',
#   'drug_form': 'Suspension',
#   'Pack_size': '15 ml',
#   'strength': '100 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '7.75'},
#  107: {'index': 107,
#   'sku_id': '421836.0',
#   'product_id': '153458.0',
#   'sku_name': 'Metapride 2mg/500mg Tablet',
#   'price': '36.0',
#   'manufacturer_name': 'Emar HealthCare',
#   'salt_name': 'Glimepiride+Metformin',
#   'drug_form': 'Tablet SR',
#   'Pack_size': '10',
#   'strength': '2mg + 500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  108: {'index': 108,
#   'sku_id': '274517.0',
#   'product_id': '56690.0',
#   'sku_name': 'Bamlo AT 5mg/50mg Tablet',
#   'price': '25.23',
#   'manufacturer_name': 'Bharti Life Sciences',
#   'salt_name': 'Amlodipine+Atenolol',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '5mg + 50mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  109: {'index': 109,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rabicip D',
#   'price': '189.00',
#   'manufacturer_name': 'Cipla Limited',
#   'salt_name': 'Rabeprazole Sodium + Domperidone (SR)',
#   'drug_form': 'Capsule',
#   'Pack_size': '15 Capsule',
#   'strength': '20 mg + 30 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '12.60'},
#  110: {'index': 110,
#   'sku_id': '425351.0',
#   'product_id': '156814.0',
#   'sku_name': 'Starpod 50mg Dry Syrup',
#   'price': '70.0',
#   'manufacturer_name': 'Minova Life Sciences Pvt Ltd',
#   'salt_name': 'Cefpodoxime Proxetil',
#   'drug_form': 'Dry Syrup',
#   'Pack_size': '30ml',
#   'strength': '50mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  111: {'index': 111,
#   'sku_id': '265442.0',
#   'product_id': '37499.0',
#   'sku_name': 'Cetoz 10mg Tablet',
#   'price': '25.0',
#   'manufacturer_name': 'Marc Laboratories Pvt Ltd',
#   'salt_name': 'Cetirizine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  112: {'index': 112,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'G Tase G (15+2) (Vencare Formulations)',
#   'price': '35.96',
#   'manufacturer_name': 'Vencare Formulations Pvt Ltd',
#   'salt_name': 'Glimepiride + Pioglitazone',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '15 mg + 2 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '3.60'},
#  113: {'index': 113,
#   'sku_id': '430135.0',
#   'product_id': '160404.0',
#   'sku_name': 'Coxpic 450mg/300mg Tablet',
#   'price': '55.0',
#   'manufacturer_name': 'Alpic Biotech Ltd',
#   'salt_name': 'Rifampicin+Isoniazid',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '450mg + 300mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  114: {'index': 114,
#   'sku_id': '142809.0',
#   'product_id': '62302.0',
#   'sku_name': 'Festive-D Eye/Ear Drops',
#   'price': '39.5',
#   'manufacturer_name': 'Laborate Pharmaceuticals India Ltd',
#   'salt_name': 'Betamethasone+Ofloxacin',
#   'drug_form': 'Eye/Ear Drops',
#   'Pack_size': '10ml',
#   'strength': '0.01% w/v + 0.3% w/v',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  115: {'index': 115,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Indap SR (1.5 mg)',
#   'price': '72.60',
#   'manufacturer_name': 'Mano (Orchid Chemicals & Pharmaceuticals Ltd.)',
#   'salt_name': 'Indapamide',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '1.5 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '7.26'},
#  116: {'index': 116,
#   'sku_id': '25226.0',
#   'product_id': '52358.0',
#   'sku_name': 'Selzic-OD 600mg Tablet ER',
#   'price': '190.57',
#   'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#   'salt_name': 'Oxcarbazepine',
#   'drug_form': 'Tablet ER',
#   'Pack_size': '10',
#   'strength': '600mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  117: {'index': 117,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Cemax OF',
#   'price': '150.00',
#   'manufacturer_name': 'Jpee Drugs',
#   'salt_name': 'Cefixime + Ofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '200 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '15.00'},
#  118: {'index': 118,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Diamet PG (500+15)',
#   'price': '27.00',
#   'manufacturer_name': 'Bal Pharma Limited',
#   'salt_name': 'Metformin + Pioglitazone',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '15 mg + 500 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.70'},
#  119: {'index': 119,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Cefluv (200 mg)',
#   'price': '115.00',
#   'manufacturer_name': 'Wisdom Pharma Pvt. Ltd',
#   'salt_name': 'Cefixime',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '200 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '11.50'},
#  120: {'index': 120,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Dexphen (2 mg)',
#   'price': '13.00',
#   'manufacturer_name': 'Santiago Life Sciences (BMW Pharmaco India Pvt Ltd)',
#   'salt_name': 'Dexchlorphexamine Maleate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '2 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '1.30'},
#  121: {'index': 121,
#   'sku_id': '465830.0',
#   'product_id': '184648.0',
#   'sku_name': 'Oflafast 200mg Tablet',
#   'price': '40.0',
#   'manufacturer_name': 'Euporie Pharmaceuticals',
#   'salt_name': 'Ofloxacin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '200mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  122: {'index': 122,
#   'sku_id': '248456.0',
#   'product_id': '34936.0',
#   'sku_name': 'Justin 25mg Tablet',
#   'price': '40.0',
#   'manufacturer_name': 'Neon Laboratories Ltd',
#   'salt_name': 'Diclofenac',
#   'drug_form': 'Tablet',
#   'Pack_size': '5',
#   'strength': '25mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  123: {'index': 123,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Clonafit Plus  Tablet',
#   'price': '133.1',
#   'manufacturer_name': 'Mankind Pharma Ltd',
#   'salt_name': 'Clonazepam+Escitalopram Oxalate',
#   'drug_form': 'Tablet',
#   'Pack_size': 'strip of 10 tablets',
#   'strength': '0.5Mg+10Mg',
#   'product_banned_flag': 'None',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  124: {'index': 124,
#   'sku_id': '468309.0',
#   'product_id': '186972.0',
#   'sku_name': 'Tarol 10mg Tablet',
#   'price': '30.0',
#   'manufacturer_name': 'Mentis Pharma Ltd',
#   'salt_name': 'Loratadine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  125: {'index': 125,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rabep',
#   'price': '89.00',
#   'manufacturer_name': 'Active Healthcare',
#   'salt_name': 'Rabeprazole',
#   'drug_form': 'Injection',
#   'Pack_size': '1 ml',
#   'strength': '20 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '89.00'},
#  126: {'index': 126,
#   'sku_id': '458841.0',
#   'product_id': '178053.0',
#   'sku_name': 'Augmax 250mg/125mg Injection',
#   'price': '58.0',
#   'manufacturer_name': 'Zencure Organics',
#   'salt_name': 'Amoxycillin + Clavulanic Acid',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '250mg + 125mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  127: {'index': 127,
#   'sku_id': '419876.0',
#   'product_id': '151615.0',
#   'sku_name': 'Triponit 90mg/48mg/100mg Tablet',
#   'price': '165.0',
#   'manufacturer_name': 'Acinom Healthcare',
#   'salt_name': 'Bromelain+Trypsin+Rutoside',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '90mg + 48mg + 100mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  128: {'index': 128,
#   'sku_id': '313490.0',
#   'product_id': '47400.0',
# ...
#   'strength': '625 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '1.95'},
#  958: {'index': 958,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Onstal (8 mg)',
#   'price': '38.00',
#   'manufacturer_name': 'Stallion Laboratories Pvt Ltd',
#   'salt_name': 'Ondansetron',
#   'drug_form': 'Injection',
#   'Pack_size': '4 ml',
#   'strength': '2 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '9.50'},
#  959: {'index': 959,
#   'sku_id': '120022.0',
#   'product_id': '87547.0',
#   'sku_name': 'Anoscha Forte Tablet',
#   'price': '305.0',
#   'manufacturer_name': 'AN Pharmaceuticals Pvt Ltd',
#   'salt_name': 'Chondroitin+Diacerein+Glucosamine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '100mg + 50mg + 750mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  960: {'index': 960,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Fevril DS (60 ml)',
#   'price': '57.00',
#   'manufacturer_name': 'Meyer Organics Pvt Ltd.',
#   'salt_name': 'Promethazine + Paracetamol',
#   'drug_form': 'Suspension',
#   'Pack_size': '60 ml',
#   'strength': '2.5 mg + 250 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '4.75'},
#  961: {'index': 961,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Restyl SR (1 mg)',
#   'price': '28.62',
#   'manufacturer_name': 'Protec (Cipla Ltd)',
#   'salt_name': 'Alprazolam',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '1 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.86'},
#  962: {'index': 962,
#   'sku_id': '339828.0',
#   'product_id': '97054.0',
#   'sku_name': 'Tenali M 1000mg/20mg Tablet ER',
#   'price': '122.33',
#   'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#   'salt_name': 'Metformin+Teneligliptin',
#   'drug_form': 'Tablet ER',
#   'Pack_size': '10',
#   'strength': '1000mg + 20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  963: {'index': 963,
#   'sku_id': '162404.0',
#   'product_id': '17189.0',
#   'sku_name': 'Etova-ER 400 Tablet',
#   'price': '119.76',
#   'manufacturer_name': 'Ipca Laboratories Ltd',
#   'salt_name': 'Etodolac',
#   'drug_form': 'Tablet ER',
#   'Pack_size': '10',
#   'strength': '400mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  964: {'index': 964,
#   'sku_id': '489120.0',
#   'product_id': '204034.0',
#   'sku_name': 'Cudase D 50mg/10mg Tablet',
#   'price': '60.0',
#   'manufacturer_name': 'Curex Laboratories Pvt Ltd',
#   'salt_name': 'Diclofenac+Serratiopeptidase',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '50mg + 10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  965: {'index': 965,
#   'sku_id': '234374.0',
#   'product_id': '8239.0',
#   'sku_name': 'Rhinomont 5 mg/10 mg Tablet',
#   'price': '121.0',
#   'manufacturer_name': 'Maneesh Pharmaceuticals Ltd',
#   'salt_name': 'Levocetirizine+Montelukast',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '5mg + 10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  966: {'index': 966,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Cardiking',
#   'price': '24.00',
#   'manufacturer_name': 'Lifecare Formulation Pvt. Ltd.',
#   'salt_name': 'Amlodipine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '24',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.40'},
#  967: {'index': 967,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Campilox LB (250+250)',
#   'price': '27.26',
#   'manufacturer_name': 'Generic (Cadila Pharmaceuticals Ltd.)',
#   'salt_name': 'Lacto Bacillus Sporegens + Cloxacillin + Ampicillin',
#   'drug_form': 'Capsule',
#   'Pack_size': '10 Capsule',
#   'strength': '60 million spores + 250 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '2.73'},
#  968: {'index': 968,
#   'sku_id': '460040.0',
#   'product_id': '179195.0',
#   'sku_name': 'Freydex Ointment',
#   'price': '34.0',
#   'manufacturer_name': 'Biomedica International',
#   'salt_name': 'Dexamethasone+Tobramycin',
#   'drug_form': 'Ointment',
#   'Pack_size': '3gm',
#   'strength': '0.1% w/w + 0.3% w/w',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  969: {'index': 969,
#   'sku_id': '515220.0',
#   'product_id': '222338.0',
#   'sku_name': 'Oxep 600mg Tablet',
#   'price': '95.7',
#   'manufacturer_name': 'Abbott',
#   'salt_name': 'Oxcarbazepine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '600mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  970: {'index': 970,
#   'sku_id': '513314.0',
#   'product_id': '220901.0',
#   'sku_name': 'Moxyrax CV 500mg/125mg Tablet',
#   'price': '188.0',
#   'manufacturer_name': 'Rax Health Care Pvt Ltd',
#   'salt_name': 'Amoxycillin + Clavulanic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '500mg + 125mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  971: {'index': 971,
#   'sku_id': '478141.0',
#   'product_id': '195348.0',
#   'sku_name': 'Nitocef Suspension',
#   'price': '52.0',
#   'manufacturer_name': 'Lezaa Biotech',
#   'salt_name': 'Cefixime',
#   'drug_form': 'Suspension',
#   'Pack_size': '30ml',
#   'strength': '50mg/5ml',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  972: {'index': 972,
#   'sku_id': '323809.0',
#   'product_id': '3835.0',
#   'sku_name': 'XeFexor-Duo Tablet',
#   'price': '89.0',
#   'manufacturer_name': 'Sparsh Remedies Pvt Ltd',
#   'salt_name': 'Flupenthixol+Escitalopram Oxalate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '0.5mg + 10mg',
#   'product_banned_flag': 'True',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  973: {'index': 973,
#   'sku_id': '481852.0',
#   'product_id': '198449.0',
#   'sku_name': 'Otrex 25mg Tablet',
#   'price': '25.0',
#   'manufacturer_name': 'Lemford Biotech Pvt Ltd',
#   'salt_name': 'Hydroxyzine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '25mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  974: {'index': 974,
#   'sku_id': '236310.0',
#   'product_id': '7451.0',
#   'sku_name': 'CELONIB 400 MG TABLET',
#   'price': '2650.0',
#   'manufacturer_name': 'Celon Laboratories Ltd',
#   'salt_name': 'Imatinib mesylate',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '400mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  975: {'index': 975,
#   'sku_id': '318436.0',
#   'product_id': '76460.0',
#   'sku_name': 'Logisil-H Cream',
#   'price': '95.0',
#   'manufacturer_name': 'Canixa Life Sciences Pvt',
#   'salt_name': 'Lidocaine/Lignocaine+Calcium Dobesilate+Hydrocortisone+Zinc',
#   'drug_form': 'Cream',
#   'Pack_size': '30gm',
#   'strength': '3% w/w + 0.25% w/w + 0.25% w/w + 5% w/w',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  976: {'index': 976,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Leucovorin Calcium (3 mg)',
#   'price': '24.00',
#   'manufacturer_name': 'Biochem Pharmaceutical Industrial Ltd',
#   'salt_name': 'Leucovorin Calcium (Folinic Acid)',
#   'drug_form': 'Injection',
#   'Pack_size': '1 Vial',
#   'strength': '3 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Vial',
#   'price_per_unit': '24.00'},
#  977: {'index': 977,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Oxoism OZ (30 ml)',
#   'price': '36.00',
#   'manufacturer_name': 'Arlak Biotech Pvt Ltd',
#   'salt_name': 'Ofloxacin + Ornidazole',
#   'drug_form': 'Syrup',
#   'Pack_size': '30 ml',
#   'strength': '50 mg + 125 mg',
#   'product_banned_flag': 'None',
#   'unit': '5 ml',
#   'price_per_unit': '6.00'},
#  978: {'index': 978,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rimpek Plus (300+450)',
#   'price': '50.35',
#   'manufacturer_name': 'Kentreck Labs Pvt Ltd.',
#   'salt_name': 'Isoniazid + Rifampicin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '450 mg + 300 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '5.04'},
#  979: {'index': 979,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Gloristat (40 mg)',
#   'price': '133.04',
#   'manufacturer_name': 'Oaknet Life Sciences Pvt. Ltd.',
#   'salt_name': 'Rosuvastatin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '40 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '13.30'},
#  980: {'index': 980,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'C Pin (5 ml)',
#   'price': '14.00',
#   'manufacturer_name': 'Calibre Pharmaceutical Pvt. Ltd.',
#   'salt_name': 'Chloramphenicol + Atropine Sulphate',
#   'drug_form': 'Drop',
#   'Pack_size': '5 ml',
#   'strength': '1% + 0.4%',
#   'product_banned_flag': 'None',
#   'unit': '1 ml',
#   'price_per_unit': '2.80'},
#  981: {'index': 981,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Omee D (10+10)',
#   'price': '36.00',
#   'manufacturer_name': 'R.K. Medicare Pvt. Ltd.',
#   'salt_name': 'Domperidone + Omeprazole',
#   'drug_form': 'Capsule',
#   'Pack_size': '10 Capsule',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '3.60'},
#  982: {'index': 982,
#   'sku_id': '230019.0',
#   'product_id': '35540.0',
#   'sku_name': 'Adzolam 0.5mg Tablet',
#   'price': '21.47',
#   'manufacturer_name': 'Aretaeus Pharmaceuticals',
#   'salt_name': 'Alprazolam',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '0.5mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  983: {'index': 983,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Ethamburose SF (800 mg)',
#   'price': '40.00',
#   'manufacturer_name': 'Medi Rose',
#   'salt_name': 'Ethambutol',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '800 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.00'},
#  984: {'index': 984,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Omitop DM (20+10)',
#   'price': '45.00',
#   'manufacturer_name': 'Ultramark Healthcare Pvt Ltd.',
#   'salt_name': 'Domperidone + Omeprazole',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '20 mg + 10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.50'},
#  985: {'index': 985,
#   'sku_id': '429397.0',
#   'product_id': '159852.0',
#   'sku_name': 'Rifaxigyl 400mg Tablet',
#   'price': '250.0',
#   'manufacturer_name': 'Medley Pharmaceuticals',
#   'salt_name': 'Rifaximin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '400mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  986: {'index': 986,
#   'sku_id': '396850.0',
#   'product_id': '133644.0',
#   'sku_name': 'Exermet P 30mg/500mg Tablet',
#   'price': '69.55',
#   'manufacturer_name': 'Cipla Ltd',
#   'salt_name': 'Pioglitazone+Metformin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '30mg + 500mg',
#   'product_banned_flag': 'True',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  987: {'index': 987,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Jolyon MD (7.5 mg)',
#   'price': '43.61',
#   'manufacturer_name': 'Lupin Laboratories Ltd.',
#   'salt_name': 'Olanzapine',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '7.5 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '4.36'},
#  988: {'index': 988,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Rexidin Plus (Mouth/Throat) (175 ml)',
#   'price': '63.15',
#   'manufacturer_name': 'Indoco Remedies Ltd',
#   'salt_name': 'Triclosan + Sodium Monofluoro Phosphate + Chlorhexidine',
#   'drug_form': 'Mouth Wash/Gargle',
#   'Pack_size': '175 ml',
#   'strength': '0.07% w/v + 0.2% w/v + 0.05% w/v',
#   'product_banned_flag': 'None',
#   'unit': '175 ml',
#   'price_per_unit': '63.15'},
#  989: {'index': 989,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Atorlip (10 mg)',
#   'price': '86.49',
#   'manufacturer_name': 'Ranbaxy Laboratories Ltd.,',
#   'salt_name': 'Atorvastatin',
#   'drug_form': 'Tablet',
#   'Pack_size': '15 Tablet',
#   'strength': '10 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '5.77'},
#  990: {'index': 990,
#   'sku_id': '405950.0',
#   'product_id': '139200.0',
#   'sku_name': 'Sardom 10mg/20mg Capsule',
#   'price': '45.0',
#   'manufacturer_name': 'Sarthak Biotech Pvt Ltd',
#   'salt_name': 'Domperidone+Omeprazole',
#   'drug_form': 'Capsule',
#   'Pack_size': '10',
#   'strength': '10mg + 20mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  991: {'index': 991,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Sparcal (1250 mg+250 iu)',
#   'price': '400.00',
#   'manufacturer_name': 'Sparkles Exim Pvt Ltd',
#   'salt_name': 'Vit D3 + Calcium Carbonate',
#   'drug_form': 'Tablet',
#   'Pack_size': '150 Tablet',
#   'strength': '250 iu + 1250 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '2.67'},
#  992: {'index': 992,
#   'sku_id': '149629.0',
#   'product_id': '59163.0',
#   'sku_name': 'Winbp CT 40/6.25 Tablet',
#   'price': '218.77',
#   'manufacturer_name': 'Abbott',
#   'salt_name': 'Olmesartan Medoxomil+Chlorthalidone',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '40mg + 6.25mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  993: {'index': 993,
#   'sku_id': '315068.0',
#   'product_id': '22938.0',
#   'sku_name': 'Gynonys H.P 500mg Injection',
#   'price': '80.72',
#   'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#   'salt_name': 'Hydroxyprogesterone',
#   'drug_form': 'Injection',
#   'Pack_size': '1',
#   'strength': '500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  994: {'index': 994,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Tranx E (250+250)',
#   'price': '122.00',
#   'manufacturer_name': 'Talson Pharmaceuticals',
#   'salt_name': 'Ethamsylate + Tranexamic Acid',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '250 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '12.20'},
#  995: {'index': 995,
#   'sku_id': '266233.0',
#   'product_id': '59126.0',
#   'sku_name': 'Amtor 5 mg/10 mg Tablet',
#   'price': '52.88',
#   'manufacturer_name': 'Alembic Pharmaceuticals Ltd',
#   'salt_name': 'Amlodipine+Atorvastatin',
#   'drug_form': 'Tablet',
#   'Pack_size': '10',
#   'strength': '5mg + 10mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  996: {'index': 996,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Kaizem CD (30 mg)',
#   'price': '15.00',
#   'manufacturer_name': 'Wockhardt Ltd.',
#   'salt_name': 'Diltiazem',
#   'drug_form': 'Capsule',
#   'Pack_size': '10 Capsule',
#   'strength': '30 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Capsule',
#   'price_per_unit': '1.50'},
#  997: {'index': 997,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Volix (0.3 mg)',
#   'price': '100.00',
#   'manufacturer_name': 'Ranbaxy Laboratories Ltd.,',
#   'salt_name': 'Voglibose',
#   'drug_form': 'Tablet',
#   'Pack_size': '10 Tablet',
#   'strength': '0.3 mg',
#   'product_banned_flag': 'None',
#   'unit': '1 Tablet',
#   'price_per_unit': '10.00'},
#  998: {'index': 998,
#   'sku_id': '530009.0',
#   'product_id': '234546.0',
#   'sku_name': 'Atizid 500mg Tablet',
#   'price': '56.0',
#   'manufacturer_name': 'DM Pharma',
#   'salt_name': 'Azithromycin',
#   'drug_form': 'Tablet',
#   'Pack_size': '3',
#   'strength': '500mg',
#   'product_banned_flag': 'False',
#   'unit': 'None',
#   'price_per_unit': 'None'},
#  999: {'index': 999,
#   'sku_id': 'None',
#   'product_id': 'None',
#   'sku_name': 'Ciprolar F (Skin) (15 gm)',
#   'price': '22.15',
#   'manufacturer_name': 'Lark Laboratories (India) Ltd.',
#   'salt_name': 'Ciprofloxacin + Fluocinolone',
#   'drug_form': 'Ointment',
#   'Pack_size': '15 gm',
#   'strength': '0.5% w/w + 0.025% w/w',
#   'product_banned_flag': 'None',
#   'unit': '15 gm',
#   'price_per_unit': '22.15'},
#  ...}
